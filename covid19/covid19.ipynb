# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('covid.csv')

# %%
import os  # Dosya dizini yani aktif dizini öğrenme
print(os.getcwd())
# Out:
# C:\Users\abdul\pythonproje

# %%
df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.000000  65.000000  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 38884            NaN  Sao Tome and Principe   0.186360   6.613081  2020-06-18
# 38885            NaN                  Yemen  15.552727  48.516388  2020-06-18
# 38886            NaN                Comoros -11.645500  43.333300  2020-06-18
# 38887            NaN             Tajikistan  38.861034  71.276093  2020-06-18
# 38888            NaN                Lesotho -29.609988  28.233608  2020-06-18
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38889 entries, 0 to 38888
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  11622 non-null  object
#  1   Country/Region  38889 non-null  object
#  2   Lat             38889 non-null  float64
#  3   Long            38889 non-null  float64
#  4   Date            38889 non-null  object
#  5   Confirmed       38889 non-null  int64
#  6   Deaths          38889 non-null  int64
#  7   Recovered       38889 non-null  int64
#  8   Active          38889 non-null  int64
#  9   WHO Region      38889 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.0+ MB

# %%
df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed',
#        'Deaths', 'Recovered', 'Active', 'WHO Region'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths      Recovered  \
# count  38889.000000  38889.000000  3.888900e+04   38889.000000   38889.000000
# mean      21.362269     23.701848  9.020540e+03     560.147754    3402.299082
# std       24.969887     70.158193  7.100308e+04    4543.654747   22340.891460
# min      -51.796300   -135.000000  0.000000e+00       0.000000       0.000000
# 25%        7.540000    -15.310100  0.000000e+00       0.000000       0.000000
# 50%       23.685000     21.758700  7.700000e+01       1.000000       9.000000
# 75%       41.204400     81.000000  8.840000e+02      12.000000     294.000000
# max       71.706900    178.065000  2.191052e+06  118434.000000  599115.000000
#
#              Active
# count  3.888900e+04
# mean   5.058093e+03
# std    4.862819e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    1.200000e+01
# 75%    3.170000e+02
# max    1.473503e+06

# %%
df.isnull().sum() #toplam boşluk sayısı
# Out:
# Province/State    27267
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
df["Province/State"].unique() #benzersiz değerler sütundaki
# Out:
# array([nan, 'Australian Capital Territory', 'New South Wales',
#        'Northern Territory', 'Queensland', 'South Australia', 'Tasmania',
#        'Victoria', 'Western Australia', 'Alberta', 'British Columbia',
#        'Manitoba', 'New Brunswick', 'Newfoundland and Labrador',
#        'Nova Scotia', 'Ontario', 'Prince Edward Island', 'Quebec',
#        'Saskatchewan', 'Anhui', 'Beijing', 'Chongqing', 'Fujian', 'Gansu',
#        'Guangdong', 'Guangxi', 'Guizhou', 'Hainan', 'Hebei',
#        'Heilongjiang', 'Henan', 'Hong Kong', 'Hubei', 'Hunan',
#        'Inner Mongolia', 'Jiangsu', 'Jiangxi', 'Jilin', 'Liaoning',
#        'Macau', 'Ningxia', 'Qinghai', 'Shaanxi', 'Shandong', 'Shanghai',
#        'Shanxi', 'Sichuan', 'Tianjin', 'Tibet', 'Xinjiang', 'Yunnan',
#        'Zhejiang', 'Faroe Islands', 'Greenland', 'French Guiana',
#        'French Polynesia', 'Guadeloupe', 'Mayotte', 'New Caledonia',
#        'Reunion', 'Saint Barthelemy', 'St Martin', 'Martinique', 'Aruba',
# ...

# %%
df["Province/State"].value_counts() # değerlerin toplamı
# Out:
# Province/State
# Australian Capital Territory    149
# Yunnan                          149
# Mayotte                         149
# Guadeloupe                      149
# French Polynesia                149
#                                ...
# Guizhou                         149
# Guangxi                         149
# Guangdong                       149
# Gansu                           149
# Saint Pierre and Miquelon       149
# Name: count, Length: 78, dtype: int64

# %%
plt.figure(figsize = (8,6))
plt.plot(df['Date'].values,df['Deaths'].values)

plt.xlabel('Date')
plt.ylabel('')
plt.title('')

plt.show()

# %%
df.groupby('Date')['Deaths'].mean()
# Out:
# Date
# 2020-01-22       0.065134
# 2020-01-23       0.068966
# 2020-01-24       0.099617
# 2020-01-25       0.160920
# 2020-01-26       0.214559
#                  ...
# 2020-06-14    1660.440613
# 2020-06-15    1673.881226
# 2020-06-16    1699.881226
# 2020-06-17    1720.088123
# 2020-06-18    1739.329502
# Name: Deaths, Length: 149, dtype: float64

# %%
plt.figure(figsize = (50,10))  #bölgelere göre gruplanmış ölüm oranları
groupdata =df.groupby('WHO Region')['Deaths'].mean()

plt.plot(groupdata.index,groupdata.values)
plt.show()
